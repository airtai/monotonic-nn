# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(export)
# Out:
# ---
#
# [source](https://github.com/airtai/monotonic-nn/blob/main/airt/_components/helpers.py#L13){target="_blank" style="float:right; font-size:smaller"}
#
# ### export
#
# >      export (o:~T, module:str='airt.keras.layers')

# %%
@export
def f():
    pass


assert f.__module__ == "airt.keras.layers"
